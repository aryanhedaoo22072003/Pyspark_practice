# %% [markdown]
# ### Data Reading JSON

# %%
df_json=spark.read.format('json').option('inferSchema',True)\
    .option('Header',True)\
    .option('multiline',False)\
    .load('/Volumes/dbacademy/default/tutorials/PysparkDataset/drivers.json')

# %%
df_json.display()

# %% [markdown]
# ### Data Reading CSV

# %%
dbutils.fs.ls('/Volumes/dbacademy/default/tutorials/PysparkDataset/')

# %%
df=spark.read.format('csv').option('inferSchema',True).option('Header',True).load('/Volumes/dbacademy/default/tutorials/PysparkDataset/BigMart Sales.csv')

# %%
df.display()

# %%
df.printSchema()

# %% [markdown]
# ### Schema Definition using DDL and StructType
# When we want to define schema according to our requirement in that case we can use this 2 above method

# %% [markdown]
# ###DDL Schema

# %%
my_ddl_schema='''
Item_Identifier STRING,
Item_Weight STRING,
Item_Fat_Content STRING,
Item_Visibility DOUBLE,
Item_Type STRING,
Item_MRP DOUBLE,
Outlet_Identifier STRING,
Outlet_Establishment_Year INTEGER,
Outlet_Size STRING,
Outlet_Location_Type STRING,
Outlet_Type STRING,
Item_Outlet_Sales DOUBLE  

'''

# %%
df=spark.read.format('csv')\
        .schema(my_ddl_schema)\
        .option('Header',True)\
        .load('/Volumes/dbacademy/default/tutorials/PysparkDataset/BigMart Sales.csv')

# %%
df.display()

# %%
df.printSchema()

# %% [markdown]
# ###StructType() Schema

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
my_struct_schema=StructType([
                StructField('Item_Identifier',StringType(),True),
                StructField('Item_Weight',StringType(),True),
                StructField('Item_Fat_Content',StringType(),True),
                StructField('Item_Visibility',StringType(),True),
                StructField('Item_Type',StringType(),True),
                StructField('Item_MRP',StringType(),True),
                StructField('Outlet_Identifier',StringType(),True),
                StructField('Outlet_Establishment_Year',StringType(),True),
                StructField('Outlet_Size',StringType(),True),
                StructField('Outlet_Location_Type',StringType(),True),
                StructField('Outlet_Type',StringType(),True),
                StructField('Item_Outlet_Sales',StringType(),True)
])

# %%
df=spark.read.format('csv')\
    .schema(my_struct_schema)\
    .option('Header',True)\
    .load('/Volumes/dbacademy/default/tutorials/PysparkDataset/BigMart Sales.csv')

# %%
df.printSchema()

# %% [markdown]
# ### SELECT STATEMENT

# %%
df.select(col('Item_Identifier'),col('Item_Weight'),col('Item_Fat_Content')).display()

# %% [markdown]
# ### Alias
# ###Basic works like as function in sql

# %%
df.select(col('Item_Identifier').alias('Item_ID')).display()

# %% [markdown]
# ###FILTER

# %% [markdown]
# ###Scenario - 1
# ###Find the data with fat content=Regular

# %%
df.filter(col('Item_Fat_Content')=='Regular').display()

# %% [markdown]
# ###Scenario-2
# ###Slice the data with item type=soft drink and weight<10

# %%
df.filter((col('Item_Type')=='Soft Drinks') & (col('Item_Weight')<10)).display()

# %% [markdown]
# ###Scenario-3
# ###Fetch the data with Tier in(Tier1 or Tier2) and outlet Size is Null

# %%
df.filter((col('Outlet_Size').isNull()) & (col('Outlet_Location_Type').isin('Tier 1','Tier 2'))).display()

# %% [markdown]
# ###WithColumnRenamed

# %%
df.withColumnRenamed('Item_Weight','Item_Wt').display()

# %% [markdown]
# ###WithColumn
# ###Scenario-1
# ###Using lit() to give constant value to a new column

# %%
df.withColumn('flag',lit('new')).display()

# %%
df.withColumn('multiply',col("Item_Weight")*col('Item_MRP')).display()

# %% [markdown]
# ###Scenerio-2
# ###Modifying existing column-use same column name in the withcolumn function
# ###using Regex_replace function to modify the data of particular column

# %%
df.withColumn('Item_Fat_Content',regexp_replace(col('Item_Fat_Content'),"Regular","Reg"))\
    .withColumn('Item_Fat_Content',regexp_replace(col("Item_Fat_Content"),"Low Fat","Lf")).display()

# %% [markdown]
# ###Type Casting
# ###Changing the datatype using .cast function

# %%
df=df.withColumn('Item_Weight',col('Item_Weight').cast(StringType()))

# %%
df.printSchema()

# %% [markdown]
# ##Sort

# %% [markdown]
# ###Scenerio-1
# ###sort by desc order for item_weight

# %%
df.sort(col('Item_Weight').desc()).display()

# %% [markdown]
# ###Scenario-2
# ###Sort by asc order for item_visibility

# %%
df.sort(col('Item_Visibility').asc()).display()

# %% [markdown]
# ###Scenario-3
# ###Multiple column to sort
# ###Both will give data in desc order

# %%
df.sort(['Item_Weight','Item_Visibility'],ascending=[0,0]).display()

# %% [markdown]
# ###Scenario-4
# ###One in ascending order and one in descending order

# %%
df.sort(['Item_Weight','Item_Visibility'],ascending=[0,1]).display()

# %% [markdown]
# ###Limit

# %%
df.limit(10).display()

# %% [markdown]
# ###DROP
# ###Scenario-1
# ###Droping 1 column

# %%
df.drop('Item_Visibility').display()

# %% [markdown]
# ###Scenario-2
# ###droping multiple column

# %%
df.drop('Item_Type','Item_Visibility').display()

# %% [markdown]
# ###Drop Duplicates(Deduplicate)
# ###Scenario-1

# %%
df.dropDuplicates().display()

# %% [markdown]
# ###Scenario-2

# %%
df.dropDuplicates(subset=['Item_Type']).display()

# %%
df.distinct().display()

# %%
df.select('Item_Type').distinct().display()
